# %%
import pandas as pd

# %%
from nba_api.stats.endpoints import teamgamelogs
team = teamgamelogs.TeamGameLogs(season_nullable='2001-02', game_segment_nullable='First Half')
a= team.get_data_frames()[0]

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        2001-02  1610612765               DET         Detroit Pistons
# 1        2001-02  1610612749               MIL         Milwaukee Bucks
# 2        2001-02  1610612766               CHH       Charlotte Hornets
# 3        2001-02  1610612751               NJN         New Jersey Nets
# 4        2001-02  1610612762               UTA               Utah Jazz
# ...          ...         ...               ...                     ...
# 2373     2001-02  1610612750               MIN  Minnesota Timberwolves
# 2374     2001-02  1610612746               LAC    Los Angeles Clippers
# 2375     2001-02  1610612759               SAS       San Antonio Spurs
# 2376     2001-02  1610612757               POR  Portland Trail Blazers
# 2377     2001-02  1610612747               LAL      Los Angeles Lakers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0     0020101181  2002-04-17T00:00:00  DET vs. MIL  W  24.0   25  ...
# 1     0020101181  2002-04-17T00:00:00    MIL @ DET  L  24.0   19  ...
# 2     0020101177  2002-04-17T00:00:00  CHH vs. CHI  W  24.0   18  ...
# 3     0020101179  2002-04-17T00:00:00    NJN @ NYK  W  24.0   15  ...
# 4     0020101184  2002-04-17T00:00:00  UTA vs. SAS  L  24.0   13  ...
# ...          ...                  ...          ... ..   ...  ...  ...
# 2373  0020100005  2001-10-30T00:00:00  MIN vs. PHI  W  24.0   19  ...
# 2374  0020100008  2001-10-30T00:00:00    LAC @ SAS  L  24.0   11  ...
# 2375  0020100008  2001-10-30T00:00:00  SAS vs. LAC  W  24.0   17  ...
# 2376  0020100012  2001-10-30T00:00:00    POR @ LAL  L  24.0   16  ...
# 2377  0020100012  2001-10-30T00:00:00  LAL vs. POR  W  24.0   22  ...
#
#       REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0          172       168      1336       494      1673        707      903
# 1         2077      1963       986       856      1101        218     1555
# 2         1348      1166      1336       113      1101        707     1220
# 3          915      2144       378       494      2162        218      308
# 4          711      1753       171       856        73       2063     1555
# ...        ...       ...       ...       ...       ...        ...      ...
# 2373      1126       452       171       856        73        707     1220
# 2374       388      2367      1652       244      2162        218     2040
# 2375       525      1166      1652      1287      1673          1     2275
# 2376      1757      1166       986      1287       637       2063      903
# 2377       388       648      1336       494       161       1279     1555
#
#       PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0           80        50               50
# 1           80      1580             2320
# 2           80      1068             1590
# 3            1      2076             1486
# 4           80      1826             1486
# ...        ...       ...              ...
# 2373        80      1334              229
# 2374        80      1580             1486
# 2375        80      1068              790
# 2376        80      1334             1879
# 2377        80       367              437
#
# [2378 rows x 56 columns]

# %%
year = '2001-02'
team = teamgamelogs.TeamGameLogs(season_nullable=year, game_segment_nullable='First Half')
b= team.get_data_frames()[0]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME  \
# 0        2001-02  1610612749               MIL       Milwaukee Bucks
# 1        2001-02  1610612755               PHI    Philadelphia 76ers
# 2        2001-02  1610612756               PHX          Phoenix Suns
# 3        2001-02  1610612754               IND        Indiana Pacers
# 4        2001-02  1610612753               ORL         Orlando Magic
# ...          ...         ...               ...                   ...
# 2373     2001-02  1610612746               LAC  Los Angeles Clippers
# 2374     2001-02  1610612745               HOU       Houston Rockets
# 2375     2001-02  1610612743               DEN        Denver Nuggets
# 2376     2001-02  1610612755               PHI    Philadelphia 76ers
# 2377     2001-02  1610612758               SAC      Sacramento Kings
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0     0020101181  2002-04-17T00:00:00    MIL @ DET  L  24.0   19  ...
# 1     0020101182  2002-04-17T00:00:00    PHI @ IND  L  24.0   16  ...
# 2     0020101185  2002-04-17T00:00:00  PHX vs. DAL  W  24.0   21  ...
# 3     0020101182  2002-04-17T00:00:00  IND vs. PHI  W  24.0   18  ...
# 4     0020101180  2002-04-17T00:00:00  ORL vs. MIA  L  24.0   18  ...
# ...          ...                  ...          ... ..   ...  ...  ...
# 2373  0020100008  2001-10-30T00:00:00    LAC @ SAS  L  24.0   11  ...
# 2374  0020100007  2001-10-30T00:00:00  HOU vs. ATL  W  24.0   19  ...
# 2375  0020100010  2001-10-30T00:00:00    DEN @ PHX  W  24.0   19  ...
# 2376  0020100005  2001-10-30T00:00:00    PHI @ MIN  L  24.0   13  ...
# 2377  0020100011  2001-10-30T00:00:00  SAC vs. SEA  W  24.0   21  ...
#
#       REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0         2077      1963       986       856      1101        218     1555
# 1         2258      1963       647       856       317       1279     1555
# 2          711        55       647       494      2162       1743      140
# 3          525       648       986       856       637       1743      563
# 4         2299      1475       986      1287      2162       1279      563
# ...        ...       ...       ...       ...       ...        ...      ...
# 2373       388      2367      1652       244      2162        218     2040
# 2374       525      1475       647      1287      1673       1743      903
# 2375        46      1475       647       113       637       1279      140
# 2376       525      1963      2109      2146      1101       2219     1220
# 2377       525       452       378       494       637        707     1220
#
#       PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0           80      1580             2320
# 1           80      2265             2151
# 2           80       367              377
# 3           80       939              207
# 4           80      1334             2173
# ...        ...       ...              ...
# 2373        80      1580             1486
# 2374        80      1468              790
# 2375        80       248               39
# 2376        80      2324             2113
# 2377        80       628              790
#
# [2378 rows x 56 columns]

# %%
df_b = pd.DataFrame(b)

# %%
df_b
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME  \
# 0        2001-02  1610612749               MIL       Milwaukee Bucks
# 1        2001-02  1610612755               PHI    Philadelphia 76ers
# 2        2001-02  1610612756               PHX          Phoenix Suns
# 3        2001-02  1610612754               IND        Indiana Pacers
# 4        2001-02  1610612753               ORL         Orlando Magic
# ...          ...         ...               ...                   ...
# 2373     2001-02  1610612746               LAC  Los Angeles Clippers
# 2374     2001-02  1610612745               HOU       Houston Rockets
# 2375     2001-02  1610612743               DEN        Denver Nuggets
# 2376     2001-02  1610612755               PHI    Philadelphia 76ers
# 2377     2001-02  1610612758               SAC      Sacramento Kings
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0     0020101181  2002-04-17T00:00:00    MIL @ DET  L  24.0   19  ...
# 1     0020101182  2002-04-17T00:00:00    PHI @ IND  L  24.0   16  ...
# 2     0020101185  2002-04-17T00:00:00  PHX vs. DAL  W  24.0   21  ...
# 3     0020101182  2002-04-17T00:00:00  IND vs. PHI  W  24.0   18  ...
# 4     0020101180  2002-04-17T00:00:00  ORL vs. MIA  L  24.0   18  ...
# ...          ...                  ...          ... ..   ...  ...  ...
# 2373  0020100008  2001-10-30T00:00:00    LAC @ SAS  L  24.0   11  ...
# 2374  0020100007  2001-10-30T00:00:00  HOU vs. ATL  W  24.0   19  ...
# 2375  0020100010  2001-10-30T00:00:00    DEN @ PHX  W  24.0   19  ...
# 2376  0020100005  2001-10-30T00:00:00    PHI @ MIN  L  24.0   13  ...
# 2377  0020100011  2001-10-30T00:00:00  SAC vs. SEA  W  24.0   21  ...
#
#       REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0         2077      1963       986       856      1101        218     1555
# 1         2258      1963       647       856       317       1279     1555
# 2          711        55       647       494      2162       1743      140
# 3          525       648       986       856       637       1743      563
# 4         2299      1475       986      1287      2162       1279      563
# ...        ...       ...       ...       ...       ...        ...      ...
# 2373       388      2367      1652       244      2162        218     2040
# 2374       525      1475       647      1287      1673       1743      903
# 2375        46      1475       647       113       637       1279      140
# 2376       525      1963      2109      2146      1101       2219     1220
# 2377       525       452       378       494       637        707     1220
#
#       PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0           80      1580             2320
# 1           80      2265             2151
# 2           80       367              377
# 3           80       939              207
# 4           80      1334             2173
# ...        ...       ...              ...
# 2373        80      1580             1486
# 2374        80      1468              790
# 2375        80       248               39
# 2376        80      2324             2113
# 2377        80       628              790
#
# [2378 rows x 56 columns]

# %%
def teamdatabyseason(year1,year2):
    year_first = year1
    year_last = year2
    all_seasons = []
    for y in season_years:
        team = teamgamelogs.TeamGameLogs(season_nullable=season_loop, game_segment_nullable='First Half')
        team = team.get_data_frames()[0]
        all_seasons.append(team)
    return all_seasons

# %% [markdown]
# '2000-01'

# %%
start_season = '1986-87'
list1=start_season.split('-')

# %%
first_part=int(list1[0])+1

# %%
first_part
# Out:
# 1987

# %%
second_part=int(list1[1])+1

# %%
type(second_part)
# Out:
# int

# %%
season_loop='-'.join([str(first_part), str(second_part)])

# %%
start_season = '2000-01'
seasons_all_list=[]
for i in range(20):
    list1=start_season.split('-')
    first_part=int(list1[0])+1
    second_part=int(list1[0])+2
    second_part=str(second_part)[2:]
    season_years='-'.join([str(first_part), str(second_part)])
    start_season=season_years
    team = teamgamelogs.TeamGameLogs(season_nullable=season_years, game_segment_nullable='First Half')
    team = team.get_data_frames()[0]
    seasons_all_list.append(team)

# %%
all_seasons_df = pd.concat(seasons_all_list, ignore_index=True)

# %%
all_seasons_df.to_csv('all_seasons_df.csv', index=False)

# %%
type(season_years)
# Out:
# str

# %%
a=4
str(a)
type(a)
# Out:
# int

# %%
teamdatabyseason(2016,2019)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-90-d21646a4c6f8> in <module>
# ----> 1 teamdatabyseason(2016,2019)
#
# <ipython-input-89-3cf6e498e023> in teamdatabyseason(year1, year2)
#       4     all_seasons = []
#       5     for y in year:
# ----> 6         team = teamgamelogs.TeamGameLogs(season_nullable=(year_first-(year_first+1)), game_segment_nullable='First Half')
#       7         team = team.get_data_frames()[0]
#       8         all_seasons.append(team)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nba_api/stats/endpoints/teamgamelogs.py in __init__(self, date_from_nullable, date_to_nullable, game_segment_nullable, last_n_games_nullable, league_id_nullable, location_nullable, measure_type_player_game_logs_nullable, month_nullable, opp_team_id_nullable, outcome_nullable, po_round_nullable, per_mode_simple_nullable, period_nullable, player_id_nullable, season_nullable, season_segment_nullable, season_type_nullable, shot_clock_range_nullable, team_id_nullable, vs_conference_nullable, vs_division_nullable, proxy, headers, timeout, get_request)
#      68         }
#      69         if get_request:
# ---> 70             self.get_request()
#      71
#      72     def get_request(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nba_api/stats/endpoints/teamgamelogs.py in get_request(self)
#      78             timeout=self.timeout,
#      79         )
# ---> 80         self.load_response()
#      81
#      82     def load_response(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nba_api/stats/endpoints/teamgamelogs.py in load_response(self)
#      81
#      82     def load_response(self):
# ---> 83         data_sets = self.nba_response.get_data_sets()
#      84         self.data_sets = [Endpoint.DataSet(data=data_set) for data_set_name, data_set in data_sets.items()]
#      85         self.team_game_logs = Endpoint.DataSet(data=data_sets['TeamGameLogs'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nba_api/stats/library/http.py in get_data_sets(self)
#      81
#      82     def get_data_sets(self):
# ---> 83         raw_dict = self.get_dict()
#      84         if 'resultSets' in raw_dict:
#      85             results = raw_dict['resultSets']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nba_api/library/http.py in get_dict(self)
#      39
#      40     def get_dict(self):
# ---> 41         return json.loads(self._response)
#      42
#      43     def get_json(self):
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
team00_01 = teamgamelogs.TeamGameLogs(season_nullable='2000-01', game_segment_nullable='First Half')
team00_01 = team00_01.get_data_frames()[0]

# %%
team00_01
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME  \
# 0        2000-01  1610612755               PHI   Philadelphia 76ers
# 1        2000-01  1610612765               DET      Detroit Pistons
# 2        2000-01  1610612764               WAS   Washington Wizards
# 3        2000-01  1610612758               SAC     Sacramento Kings
# 4        2000-01  1610612754               IND       Indiana Pacers
# ...          ...         ...               ...                  ...
# 2373     2000-01  1610612756               PHX         Phoenix Suns
# 2374     2000-01  1610612759               SAS    San Antonio Spurs
# 2375     2000-01  1610612752               NYK      New York Knicks
# 2376     2000-01  1610612739               CLE  Cleveland Cavaliers
# 2377     2000-01  1610612747               LAL   Los Angeles Lakers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0     0020001181  2001-04-18T00:00:00  PHI vs. CHI  L  24.0   18  ...
# 1     0020001180  2001-04-18T00:00:00    DET @ NYK  L  24.0   18  ...
# 2     0020001182  2001-04-18T00:00:00  WAS vs. TOR  L  24.0   20  ...
# 3     0020001186  2001-04-18T00:00:00    SAC @ DEN  L  24.0   16  ...
# 4     0020001184  2001-04-18T00:00:00    IND @ CLE  W  24.0   20  ...
# ...          ...                  ...          ... ..   ...  ...  ...
# 2373  0020000011  2000-10-31T00:00:00    PHX @ GSW  L  24.0   22  ...
# 2374  0020000009  2000-10-31T00:00:00  SAS vs. IND  W  24.0   19  ...
# 2375  0020000001  2000-10-31T00:00:00  NYK vs. PHI  L  24.0   15  ...
# 2376  0020000002  2000-10-31T00:00:00    CLE @ NJN  W  24.0   16  ...
# 2377  0020000012  2000-10-31T00:00:00    LAL @ POR  W  24.0   21  ...
#
#       REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0         1343       675      2295       498      2149        720      693
# 1         1545      1461       937       854      1660        231     1674
# 2          739      1713      1871      2125      1151        720      417
# 3          739       905      1274        48       651       1229      214
# 4          922       187       937      1731        28        231     1356
# ...        ...       ...       ...       ...       ...        ...      ...
# 2373       155       675      1583       854       651        720     2293
# 2374      1741      1461      1274       854      1151        720      693
# 2375      2053      1183       937       498      1151       2038     1916
# 2376       101      1713      2295      1731       342       2038     1916
# 2377      1545        49      2051      2125      1151        231     1022
#
#       PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0           50      1677             1765
# 1           50       992             2021
# 2           50      1332             1765
# 3           50      1100             1765
# 4            1      1100             1599
# ...        ...       ...              ...
# 2373        50       330              543
# 2374        50       743              359
# 2375        50      1872             1966
# 2376        50      1557             1143
# 2377        50       564              414
#
# [2378 rows x 56 columns]

# %%
from nba_api.stats.endpoints import teamgamelogs

team01_02 = teamgamelogs.TeamGameLogs(season_nullable='2001-02', game_segment_nullable='First Half')
team01_02 = team01_02.get_data_frames()[0]

# %%
team01_02
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        2001-02  1610612765               DET         Detroit Pistons
# 1        2001-02  1610612749               MIL         Milwaukee Bucks
# 2        2001-02  1610612766               CHH       Charlotte Hornets
# 3        2001-02  1610612751               NJN         New Jersey Nets
# 4        2001-02  1610612762               UTA               Utah Jazz
# ...          ...         ...               ...                     ...
# 2373     2001-02  1610612750               MIN  Minnesota Timberwolves
# 2374     2001-02  1610612746               LAC    Los Angeles Clippers
# 2375     2001-02  1610612759               SAS       San Antonio Spurs
# 2376     2001-02  1610612757               POR  Portland Trail Blazers
# 2377     2001-02  1610612747               LAL      Los Angeles Lakers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0     0020101181  2002-04-17T00:00:00  DET vs. MIL  W  24.0   25  ...
# 1     0020101181  2002-04-17T00:00:00    MIL @ DET  L  24.0   19  ...
# 2     0020101177  2002-04-17T00:00:00  CHH vs. CHI  W  24.0   18  ...
# 3     0020101179  2002-04-17T00:00:00    NJN @ NYK  W  24.0   15  ...
# 4     0020101184  2002-04-17T00:00:00  UTA vs. SAS  L  24.0   13  ...
# ...          ...                  ...          ... ..   ...  ...  ...
# 2373  0020100005  2001-10-30T00:00:00  MIN vs. PHI  W  24.0   19  ...
# 2374  0020100008  2001-10-30T00:00:00    LAC @ SAS  L  24.0   11  ...
# 2375  0020100008  2001-10-30T00:00:00  SAS vs. LAC  W  24.0   17  ...
# 2376  0020100012  2001-10-30T00:00:00    POR @ LAL  L  24.0   16  ...
# 2377  0020100012  2001-10-30T00:00:00  LAL vs. POR  W  24.0   22  ...
#
#       REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0          172       168      1336       494      1673        707      903
# 1         2077      1963       986       856      1101        218     1555
# 2         1348      1166      1336       113      1101        707     1220
# 3          915      2144       378       494      2162        218      308
# 4          711      1753       171       856        73       2063     1555
# ...        ...       ...       ...       ...       ...        ...      ...
# 2373      1126       452       171       856        73        707     1220
# 2374       388      2367      1652       244      2162        218     2040
# 2375       525      1166      1652      1287      1673          1     2275
# 2376      1757      1166       986      1287       637       2063      903
# 2377       388       648      1336       494       161       1279     1555
#
#       PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0           80        50               50
# 1           80      1580             2320
# 2           80      1068             1590
# 3            1      2076             1486
# 4           80      1826             1486
# ...        ...       ...              ...
# 2373        80      1334              229
# 2374        80      1580             1486
# 2375        80      1068              790
# 2376        80      1334             1879
# 2377        80       367              437
#
# [2378 rows x 56 columns]

# %%
result = team00_01.append(team01_02, ignore_index=True)

# %%
result
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        2000-01  1610612755               PHI      Philadelphia 76ers
# 1        2000-01  1610612765               DET         Detroit Pistons
# 2        2000-01  1610612764               WAS      Washington Wizards
# 3        2000-01  1610612758               SAC        Sacramento Kings
# 4        2000-01  1610612754               IND          Indiana Pacers
# ...          ...         ...               ...                     ...
# 4751     2001-02  1610612750               MIN  Minnesota Timberwolves
# 4752     2001-02  1610612746               LAC    Los Angeles Clippers
# 4753     2001-02  1610612759               SAS       San Antonio Spurs
# 4754     2001-02  1610612757               POR  Portland Trail Blazers
# 4755     2001-02  1610612747               LAL      Los Angeles Lakers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0     0020001181  2001-04-18T00:00:00  PHI vs. CHI  L  24.0   18  ...
# 1     0020001180  2001-04-18T00:00:00    DET @ NYK  L  24.0   18  ...
# 2     0020001182  2001-04-18T00:00:00  WAS vs. TOR  L  24.0   20  ...
# 3     0020001186  2001-04-18T00:00:00    SAC @ DEN  L  24.0   16  ...
# 4     0020001184  2001-04-18T00:00:00    IND @ CLE  W  24.0   20  ...
# ...          ...                  ...          ... ..   ...  ...  ...
# 4751  0020100005  2001-10-30T00:00:00  MIN vs. PHI  W  24.0   19  ...
# 4752  0020100008  2001-10-30T00:00:00    LAC @ SAS  L  24.0   11  ...
# 4753  0020100008  2001-10-30T00:00:00  SAS vs. LAC  W  24.0   17  ...
# 4754  0020100012  2001-10-30T00:00:00    POR @ LAL  L  24.0   16  ...
# 4755  0020100012  2001-10-30T00:00:00  LAL vs. POR  W  24.0   22  ...
#
#       REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0         1343       675      2295       498      2149        720      693
# 1         1545      1461       937       854      1660        231     1674
# 2          739      1713      1871      2125      1151        720      417
# 3          739       905      1274        48       651       1229      214
# 4          922       187       937      1731        28        231     1356
# ...        ...       ...       ...       ...       ...        ...      ...
# 4751      1126       452       171       856        73        707     1220
# 4752       388      2367      1652       244      2162        218     2040
# 4753       525      1166      1652      1287      1673          1     2275
# 4754      1757      1166       986      1287       637       2063      903
# 4755       388       648      1336       494       161       1279     1555
#
#       PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0           50      1677             1765
# 1           50       992             2021
# 2           50      1332             1765
# 3           50      1100             1765
# 4            1      1100             1599
# ...        ...       ...              ...
# 4751        80      1334              229
# 4752        80      1580             1486
# 4753        80      1068              790
# 4754        80      1334             1879
# 4755        80       367              437
#
# [4756 rows x 56 columns]

# %%
team00_01 = teamgamelogs.TeamGameLogs(season_nullable='2000-01', game_segment_nullable='First Half')
team00_01 = team00_01.get_data_frames()[0]

team01_02 = teamgamelogs.TeamGameLogs(season_nullable='2001-02', game_segment_nullable='First Half')
team01_02 = team01_02.get_data_frames()[0]

team02_03 = teamgamelogs.TeamGameLogs(season_nullable='2002-03', game_segment_nullable='First Half')
team02_03 = team02_03.get_data_frames()[0]

team03_04 = teamgamelogs.TeamGameLogs(season_nullable='2003-04', game_segment_nullable='First Half')
team03_04 = team03_04.get_data_frames()[0]

team04_05 = teamgamelogs.TeamGameLogs(season_nullable='2004-05', game_segment_nullable='First Half')
team04_05 = team04_05.get_data_frames()[0]

team05_06 = teamgamelogs.TeamGameLogs(season_nullable='2005-06', game_segment_nullable='First Half')
team05_06 = team05_06.get_data_frames()[0]

team06_07 = teamgamelogs.TeamGameLogs(season_nullable='2006-07', game_segment_nullable='First Half')
team06_07 = team06_07.get_data_frames()[0]

team07_08 = teamgamelogs.TeamGameLogs(season_nullable='2007-08', game_segment_nullable='First Half')
team07_08 = team07_08.get_data_frames()[0]

team08_09 = teamgamelogs.TeamGameLogs(season_nullable='2008-09', game_segment_nullable='First Half')
team08_09 = team08_09.get_data_frames()[0]

team09_10 = teamgamelogs.TeamGameLogs(season_nullable='2009-10', game_segment_nullable='First Half')
team09_10 = team09_10.get_data_frames()[0]

team10_11 = teamgamelogs.TeamGameLogs(season_nullable='2010-11', game_segment_nullable='First Half')
team10_11 = team10_11.get_data_frames()[0]

team11_12 = teamgamelogs.TeamGameLogs(season_nullable='2011-12', game_segment_nullable='First Half')
team11_12 = team11_12.get_data_frames()[0]

team12_13 = teamgamelogs.TeamGameLogs(season_nullable='2012-13', game_segment_nullable='First Half')
team12_13 = team12_13.get_data_frames()[0]

team13_14 = teamgamelogs.TeamGameLogs(season_nullable='2013-14', game_segment_nullable='First Half')
team13_14 = team13_14.get_data_frames()[0]

team14_15 = teamgamelogs.TeamGameLogs(season_nullable='2014-15', game_segment_nullable='First Half')
team14_15 = team14_15.get_data_frames()[0]

team15_16 = teamgamelogs.TeamGameLogs(season_nullable='2015-16', game_segment_nullable='First Half')
team15_16 = team15_16.get_data_frames()[0]

team16_17 = teamgamelogs.TeamGameLogs(season_nullable='2016-17', game_segment_nullable='First Half')
team16_17 = team16_17.get_data_frames()[0]

team17_18 = teamgamelogs.TeamGameLogs(season_nullable='2017-18', game_segment_nullable='First Half')
team17_18 = team17_18.get_data_frames()[0]

team18_19 = teamgamelogs.TeamGameLogs(season_nullable='2018-19', game_segment_nullable='First Half')
team18_19 = team18_19.get_data_frames()[0]

team19_20 = teamgamelogs.TeamGameLogs(season_nullable='2019-20', game_segment_nullable='First Half')
team19_20 = team19_20.get_data_frames()[0]

# %%
seasons_00_20_df = pd.concat([team00_01, team01_02, team02_03, team03_04, team04_05,
                        team05_06, team06_07, team07_08, team08_09, team09_10,
                        team10_11, team11_12, team12_13, team13_14, team14_15,
                        team15_16, team16_17, team17_18, team18_19, team19_20],
                        ignore_index=True)

# %%
seasons_00_20_df
# Out:
#       SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0         2000-01  1610612750               MIN  Minnesota Timberwolves
# 1         2000-01  1610612762               UTA               Utah Jazz
# 2         2000-01  1610612742               DAL        Dallas Mavericks
# 3         2000-01  1610612765               DET         Detroit Pistons
# 4         2000-01  1610612763               VAN     Vancouver Grizzlies
# ...           ...         ...               ...                     ...
# 48043     2019-20  1610612743               DEN          Denver Nuggets
# 48044     2019-20  1610612761               TOR         Toronto Raptors
# 48045     2019-20  1610612747               LAL      Los Angeles Lakers
# 48046     2019-20  1610612746               LAC             LA Clippers
# 48047     2019-20  1610612740               NOP    New Orleans Pelicans
#
#           GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  ...  \
# 0      0020001185  2001-04-18T00:00:00    MIN @ DAL  L  24.0   19  ...
# 1      0020001187  2001-04-18T00:00:00    UTA @ PHX  L  24.0   17  ...
# 2      0020001185  2001-04-18T00:00:00  DAL vs. MIN  W  24.0   25  ...
# 3      0020001180  2001-04-18T00:00:00    DET @ NYK  L  24.0   18  ...
# 4      0020001188  2001-04-18T00:00:00    VAN @ GSW  W  24.0   20  ...
# ...           ...                  ...          ... ..   ...  ...  ...
# 48043  0021900013  2019-10-23T00:00:00    DEN @ POR  W  24.0   17  ...
# 48044  0021900001  2019-10-22T00:00:00  TOR vs. NOP  W  24.0   18  ...
# 48045  0021900002  2019-10-22T00:00:00    LAL @ LAC  L  24.0   18  ...
# 48046  0021900002  2019-10-22T00:00:00  LAC vs. LAL  W  24.0   24  ...
# 48047  0021900001  2019-10-22T00:00:00    NOP @ TOR  L  24.0   22  ...
#
#        REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0           547       675       318       498      1660       1229      693
# 1           547       905      2369      1731      1660          1     1916
# 2           311       465      1583      1731       651        231     1916
# 3          1545      1461       937       854      1660        231     1674
# 4            64      1713      1274       854       180       2200      214
# ...         ...       ...       ...       ...       ...        ...      ...
# 48043       511       852      2048       206       492        646     1375
# 48044        37      1894      1972      1133      1474       2013     1375
# 48045      2018      1737       581      1133       221       1196     1974
# 48046       861      1334       882      1133       492       1628     2078
# 48047       511        88       882       714        37        217     2039
#
#        PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0            50       857             2122
# 1            50      1872             1418
# 2            50        62              222
# 3            50       992             2021
# 4            50      1445             1335
# ...         ...       ...              ...
# 48043       268      1184              749
# 48044        42       989             1371
# 48045        26      1184             1588
# 48046        81       495              465
# 48047       447       565              666
#
# [48048 rows x 56 columns]
