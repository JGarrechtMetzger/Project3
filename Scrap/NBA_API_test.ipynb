# %%
from nba_api.stats.static import teams

nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
from nba_api.stats.endpoints import leaguegamefinder

# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22020  1610612738               BOS  Boston Celtics  0022000280
# 1     22020  1610612738               BOS  Boston Celtics  0022000262
# 2     22020  1610612738               BOS  Boston Celtics  0022000250
# 3     22020  1610612738               BOS  Boston Celtics  0022000233
# 4     22020  1610612738               BOS  Boston Celtics  0022000218
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2021-01-27    BOS @ SAS  L  239  106  ...   0.857    13    26   39   15
# 1  2021-01-25    BOS @ CHI  W  239  119  ...   0.800     6    38   44   28
# 2  2021-01-24  BOS vs. CLE  W  239  141  ...   0.852    13    42   55   26
# 3  2021-01-22    BOS @ PHI  L  239  110  ...   0.800    10    22   32   23
# 4  2021-01-20    BOS @ PHI  L  240  109  ...   0.650    10    35   45   22
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0   10    4   10  14        -4.0
# ...

# %%
# Subset the games to when the last 4 digits of SEASON_ID were 2017.
games_1718 = games[games.SEASON_ID.str[-4:] == '2000']
games_1718.head()
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 1931     22000  1610612738               BOS  Boston Celtics  0020001179
# 1932     22000  1610612738               BOS  Boston Celtics  0020001154
# 1933     22000  1610612738               BOS  Boston Celtics  0020001142
# 1934     22000  1610612738               BOS  Boston Celtics  0020001125
# 1935     22000  1610612738               BOS  Boston Celtics  0020001112
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 1931  2001-04-18  BOS vs. CHH  L  240   92  ...   0.840    11    31   42   18
# 1932  2001-04-15  BOS vs. NJN  W  241   95  ...   0.688    14    36   50   26
# 1933  2001-04-13    BOS @ IND  L  265  108  ...   0.737    13    32   45   24
# 1934  2001-04-11  BOS vs. MIA  L  239   97  ...   0.867     9    22   31   14
# 1935  2001-04-09    BOS @ PHI  L  240   95  ...   0.692    10    20   30   23
#
#       STL  BLK  TOV  PF  PLUS_MINUS
# ...

# %%
from nba_api.stats.endpoints import playbyplayv2
pbp = playbyplayv2.PlayByPlayV2('0020001179')
pbp = pbp.get_data_frames()[0]
pbp.head(20)
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0   0020001179         0            12                   0       1
# 1   0020001179         1            10                   0       1
# 2   0020001179         2             6                   2       1
# 3   0020001179         3             3                  11       1
# 4   0020001179         4             3                  12       1
# 5   0020001179         5             1                   1       1
# 6   0020001179         6             1                   1       1
# 7   0020001179         7             1                   1       1
# 8   0020001179         8             1                   1       1
# 9   0020001179         9             2                   1       1
# 10  0020001179        10             4                   0       1
# 11  0020001179        11             5                   1       1
# 12  0020001179        12             1                   1       1
# ...

# %%
type(pbp)
# Out:
# pandas.core.frame.DataFrame

# %%
pbp.shape
# Out:
# (463, 34)

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
nba_1 = games_1718

# %%
engine = create_engine('postgresql://johnmetzger:localhost@localhost:5432/nba_1')

# %%
nba_1.to_sql('nba_1',engine,index=False)

# %%
query = 'SELECT * FROM nba_1;'
df = pd.read_sql(query, engine)

df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22000  1610612738               BOS  Boston Celtics  0020001179
# 1     22000  1610612738               BOS  Boston Celtics  0020001154
# 2     22000  1610612738               BOS  Boston Celtics  0020001142
# 3     22000  1610612738               BOS  Boston Celtics  0020001125
# 4     22000  1610612738               BOS  Boston Celtics  0020001112
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2001-04-18  BOS vs. CHH  L  240   92  ...   0.840    11    31   42   18
# 1  2001-04-15  BOS vs. NJN  W  241   95  ...   0.688    14    36   50   26
# 2  2001-04-13    BOS @ IND  L  265  108  ...   0.737    13    32   45   24
# 3  2001-04-11  BOS vs. MIA  L  239   97  ...   0.867     9    22   31   14
# 4  2001-04-09    BOS @ PHI  L  240   95  ...   0.692    10    20   30   23
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0   10    6   13  22        -5.0
# ...

# %%
from nba_py import team

# %%
from nba_api.stats.endpoints import teamdashboardbygeneralsplits
# Anthony Davis
career = teamdashboardbygeneralsplits.TeamDashboardByGeneralSplits(team_id='1610612738')
career.get_data_frames()[1]
# Out:
#   GROUP_SET GROUP_VALUE TEAM_GAME_LOCATION  GP  W  L  W_PCT    MIN  FGM  FGA  \
# 0  Location        Home               Home   8  5  3  0.625  384.0  337  723
# 1  Location        Road               Road  10  5  5  0.500  480.0  420  876
#
#    ...  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  ...         1         1         2          1        1         2         2
# 1  ...         2         2         1          2        2         1         1
#
#    PLUS_MINUS_RANK  CFID  CFPARAMS
# 0                1   153      Home
# 1                2   153      Road
#
# [2 rows x 57 columns]

# %%
career

# %%
career.game_segment
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-f39382faf90b> in <module>
# ----> 1 career.game_segment
#
# AttributeError: 'TeamDashboardByGeneralSplits' object has no attribute 'game_segment'

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('max_columns', None)

# %%
from nba_api.stats.endpoints import teamgamelogs
# Anthony Davis
team = teamgamelogs.TeamGameLogs(game_segment_nullable='First Half', date_from_nullable='2000-2001', date_to_nullable='2001-2002')
a= team.get_data_frames()[1]
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-69-4cbf9d31a19f> in <module>
#       1 from nba_api.stats.endpoints import teamgamelogs
#       2 # Anthony Davis
# ----> 3 team = teamgamelogs.TeamGameLogs(game_segment_nullable='First Half', date_from_nullable='2000-2001', date_to_nullable='2001-2002')
#       4 a= team.get_data_frames()[1]
#
# ...

# %%
df = pd.DataFrame(a)

# %%
len(df.TEAM_ID.unique())
# Out:
# 29

# %%
get_date_format()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-e868e9b4edc6> in <module>
# ----> 1 get_date_format()
#
# NameError: name 'get_date_format' is not defined

# %%
df
# Out:
# Empty DataFrame
# Columns: [SEASON_YEAR, TEAM_ID, TEAM_ABBREVIATION, TEAM_NAME, GAME_ID, GAME_DATE, MATCHUP, WL, MIN, FGM, FGA, FG_PCT, FG3M, FG3A, FG3_PCT, FTM, FTA, FT_PCT, OREB, DREB, REB, AST, TOV, STL, BLK, BLKA, PF, PFD, PTS, PLUS_MINUS, GP_RANK, W_RANK, L_RANK, W_PCT_RANK, MIN_RANK, FGM_RANK, FGA_RANK, FG_PCT_RANK, FG3M_RANK, FG3A_RANK, FG3_PCT_RANK, FTM_RANK, FTA_RANK, FT_PCT_RANK, OREB_RANK, DREB_RANK, REB_RANK, AST_RANK, TOV_RANK, STL_RANK, BLK_RANK, BLKA_RANK, PF_RANK, PFD_RANK, PTS_RANK, PLUS_MINUS_RANK]
# Index: []
