# %%
import pandas as pd

# %%
from nba_py import team

# %%
spurs = teamdashboardbygamesplits.TeamDashboardByGameSplits(team_id='1610612759') spurs.get_data_frames()[1]
# Out:
#   File "<ipython-input-100-5f9ef2e546f1>", line 1
#     spurs = teamdashboardbygamesplits.TeamDashboardByGameSplits(team_id='1610612759') spurs.get_data_frames()[1]
#                                                                                       ^
# SyntaxError: invalid syntax

# %%
from nba_api.stats.static import teams
teams.find_team_name_by_id(1610612739)
# Out:
# {'id': 1610612739,
#  'full_name': 'Cleveland Cavaliers',
#  'abbreviation': 'CLE',
#  'nickname': 'Cavaliers',
#  'city': 'Cleveland',
#  'state': 'Ohio',
#  'year_founded': 1970}

# %%
a
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP    WL     W    L  W_PCT  \
# 0   1610612759  0022000304  JAN 30, 2021  SAS vs. MEM  None   NaN  NaN    NaN
# 1   1610612759  0022000296  JAN 29, 2021  SAS vs. DEN     W  11.0  8.0  0.579
# 2   1610612759  0022000280  JAN 27, 2021  SAS vs. BOS     W  10.0  8.0  0.556
# 3   1610612759  0022000253  JAN 24, 2021  SAS vs. WAS     W   9.0  8.0  0.529
# 4   1610612759  0022000237  JAN 22, 2021  SAS vs. DAL     L   8.0  8.0  0.500
# 5   1610612759  0022000223  JAN 20, 2021    SAS @ GSW     L   8.0  7.0  0.533
# 6   1610612759  0022000207  JAN 18, 2021    SAS @ POR     W   8.0  6.0  0.571
# 7   1610612759  0022000189  JAN 16, 2021  SAS vs. HOU     W   7.0  6.0  0.538
# 8   1610612759  0022000176  JAN 14, 2021  SAS vs. HOU     L   6.0  6.0  0.500
# 9   1610612759  0022000162  JAN 12, 2021    SAS @ OKC     W   6.0  5.0  0.545
# 10  1610612759  0022000147  JAN 10, 2021    SAS @ MIN     L   5.0  5.0  0.500
# ...

# %%
a.shape
# Out:
# (20, 27)

# %%
d
# Out:
#   GROUP_SET GROUP_VALUE  GP   W  L  W_PCT    MIN  FGM   FGA  FG_PCT  FG3M  \
# 0   Overall     2020-21  19  11  8  0.579  917.0  805  1763   0.457   209
#
#    FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST    TOV  STL  BLK  \
# 0   575    0.363  303  385   0.787   183   687  870  475  206.0  134   90
#
#    BLKA   PF  PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  L_RANK  W_PCT_RANK  \
# 0   107  334  351  2122        26.0        1       1       1           1
#
#    MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  FG3A_RANK  \
# 0         1         1         1            1          1          1
#
#    FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  DREB_RANK  \
# 0             1         1         1            1          1          1
#
#    REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  \
# 0         1         1         1         1         1          1        1
#
#    PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  CFID CFPARAMS
# ...

# %%
## This will allow me to see all the data columns

pd.set_option('display.max_columns', None)

# %%
a.head()
# Out:
#   GROUP_SET  GROUP_VALUE  GP   W  L  W_PCT    MIN  FGM  FGA  FG_PCT  FG3M  \
# 0   By Half   First Half  19  11  8  0.579  456.0  404  893   0.452   111
# 1   By Half  Second Half  19  11  8  0.579  456.0  397  860   0.462    96
# 2   By Half     Overtime   1   1  0  1.000    5.0    4   10   0.400     2
#
#    FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST    TOV  STL  BLK  \
# 0   293    0.379  129  163   0.791    73   356  429  253   97.0   70   46
# 1   278    0.345  172  220   0.782   107   329  436  219  109.0   63   43
# 2     4    0.500    2    2   1.000     3     2    5    3    0.0    1    1
#
#    BLKA   PF  PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  L_RANK  W_PCT_RANK  \
# 0    51  149  150  1048        23.0        1       1       2           2
# 1    55  183  200  1062         0.0        1       1       2           2
# 2     1    2    1    12         3.0        3       3       1           1
#
#    MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  FG3A_RANK  \
# ...

# %%
from nba_py import constants
print(constants.SeasonType.Regular)
# Out:
# Regular Season

# %%
from nba_py import game
class GameSegment(0022000304'):
    FirstHalf = 'First Half'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-c516456dd89f> in <module>
#       1 from nba_py import game
# ----> 2 class GameSegment('0021600457'):
#       3     FirstHalf = 'First Half'
#
# TypeError: str() argument 2 must be str, not tuple

# %%
print(constants)
# Out:
# <module 'nba_py.constants' from '/Users/johnmetzger/opt/anaconda3/lib/python3.8/site-packages/nba_py/constants.py'>

# %%
class GameSegment(FirstHalf, '0021600457'):
# Out:
#   File "<ipython-input-105-beeabddd7d2d>", line 1
#     class GameSegment(FirstHalf, '0021600457'):
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
from nba_api.stats.endpoints import commonplayerinfo

# Basic Request
player_info = commonplayerinfo.CommonPlayerInfo(player_id=2544)

# %%
player_info

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
# 8     203076   2020-21        00  1610612747               LAL        27.0
#
#    GP  GS     MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  \
# 0  64  60  1846.0  349   676   0.516     0     6    0.000  169  225   0.751
# ...
